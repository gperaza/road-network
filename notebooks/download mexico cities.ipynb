# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pathlib
import time
import contextily as ctx # for basemaps
import os
import datetime
# %matplotlib inline

# %%
# turn response caching on and turn on logging to your terminal window
ox.config(log_console=True, use_cache=True)

ox.__version__
# Out:
# '1.0.1'

# %% [markdown]
# ## Read Census data

# %%
mexico_censo = pd.read_csv('input_data/censo_mexico_2020_csv/iter_00_cpv2020/conjunto_de_datos/conjunto_de_datos_iter_00CSV20.csv', encoding='utf-8', low_memory=False)

# %%
mexico_censo.columns
# Out:
# Index(['ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC', 'LONGITUD',
#        'LATITUD', 'ALTITUD', 'POBTOT',
#        ...
#        'VPH_CEL', 'VPH_INTER', 'VPH_STVP', 'VPH_SPMVPI', 'VPH_CVJ',
#        'VPH_SINRTV', 'VPH_SINLTC', 'VPH_SINCINT', 'VPH_SINTIC', 'TAMLOC'],
#       dtype='object', length=232)

# %%
# get data of cdmx as this is a special case (review later)
cdmx = mexico_censo[mexico_censo['ENTIDAD'] == 9]

# %%
# drop the different totals there are in the dataframe, which may affect the results when sorting by population
mexico_censo.drop(mexico_censo[(mexico_censo['LOC'] == 0) | (mexico_censo['LOC'] == 9998) | (mexico_censo['LOC'] == 9999)].index, inplace=True)
mexico_censo.reset_index(inplace=True, drop=True)

# %%
# select only some columns
mexico_censo = mexico_censo[['ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC', 'POBTOT']]

# %%
# sort by population to find the most populated cities
mexico_censo_sorted_by_population = mexico_censo.sort_values(by=['POBTOT'], ascending=False)

# %%
# get the first 100 most populated cities
mexico_censo_sorted_by_population_top100 = mexico_censo_sorted_by_population.head(100)

# %%
mexico_censo_sorted_by_population_top100.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Read Marco Geoestadistico data

# %%
mexico_MG = gpd.read_file('input_data/marco_geoestadistico_2020/MG_2020_Integrado/conjunto_de_datos/00l.shp')

# %% [markdown]
# ## Prepare data for merging

# %%
# We need to add some zeros to the values on the elements from the CENSO 2020 dataframe that conform the CVEGEO.
#data.loc[:, ['ENTIDAD']] = data.loc[:, ['ENTIDAD']].applymap('{0:0>2}'.format)
#data.loc[:, ['MUN']] = data.loc[:, ['MUN']].applymap('{0:0>3}'.format)
#data.loc[:, ['LOC']] = data.loc[:, ['LOC']].applymap('{0:0>4}'.format)
mexico_censo_sorted_by_population_top100['ENTIDAD'] = mexico_censo_sorted_by_population_top100['ENTIDAD'].apply(lambda x: '{0:0>2}'.format(x))
mexico_censo_sorted_by_population_top100['MUN'] = mexico_censo_sorted_by_population_top100['MUN'].apply(lambda x: '{0:0>3}'.format(x))
mexico_censo_sorted_by_population_top100['LOC'] = mexico_censo_sorted_by_population_top100['LOC'].apply(lambda x: '{0:0>4}'.format(x))
# Out:
# <ipython-input-14-ef1874bbc4ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mexico_censo_sorted_by_population_top100['ENTIDAD'] = mexico_censo_sorted_by_population_top100['ENTIDAD'].apply(lambda x: '{0:0>2}'.format(x))
# <ipython-input-14-ef1874bbc4ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mexico_censo_sorted_by_population_top100['MUN'] = mexico_censo_sorted_by_population_top100['MUN'].apply(lambda x: '{0:0>3}'.format(x))
# <ipython-input-14-ef1874bbc4ea>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mexico_censo_sorted_by_population_top100['LOC'] = mexico_censo_sorted_by_population_top100['LOC'].apply(lambda x: '{0:0>4}'.format(x))

# %%
# convert column values into strings
mexico_censo_sorted_by_population_top100 = mexico_censo_sorted_by_population_top100.astype({'ENTIDAD':str, 'MUN':str, 'LOC':str})

# %%
# Concatenate columns to create the CVEGEO columns
mexico_censo_sorted_by_population_top100['CVEGEO'] = mexico_censo_sorted_by_population_top100['ENTIDAD'] + mexico_censo_sorted_by_population_top100['MUN'] + mexico_censo_sorted_by_population_top100['LOC']
mexico_censo_sorted_by_population_top100.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Merge dataframes

# %%
#yucatan_ageb_marcogeo2020.sort_values(by=['CVEGEO'], ignore_index=True, inplace=True)

#drop columns that are duplicated in the other dataframe
mexico_censo_sorted_by_population_top100.drop(columns=['ENTIDAD', 'MUN', 'LOC'], inplace = True)
mexico_MG.drop(columns=['NOMGEO', 'AMBITO'], inplace=True)

mexico_pop_top100 = mexico_MG.merge(mexico_censo_sorted_by_population_top100, on=['CVEGEO'], how='inner')

# %%
mexico_pop_top100 = mexico_pop_top100.sort_values(by=['POBTOT'], ascending=False)
mexico_pop_top100.reset_index(inplace=True, drop=True)

# %%
mexico_pop_top100
# Out:
#        CVEGEO CVE_ENT CVE_MUN CVE_LOC  \
# 0   090070001      09     007    0001
# 1   020040001      02     004    0001
# 2   150330001      15     033    0001
# 3   110200001      11     020    0001
# 4   211140001      21     114    0001
# ..        ...     ...     ...     ...
# 95  070780001      07     078    0001
# 96  301310001      30     131    0001
# 97  220160001      22     016    0001
# 98  260550001      26     055    0001
# 99  150250001      15     025    0001
#
#                                              geometry  \
# 0   POLYGON ((2808094.185 825698.592, 2808093.949 ...
# 1   MULTIPOLYGON (((1086114.495 2332537.239, 10861...
# 2   POLYGON ((2807108.766 854056.556, 2807126.042 ...
# 3   MULTIPOLYGON (((2541248.094 1004738.337, 25414...
# 4   POLYGON ((2896301.113 798603.947, 2896323.425 ...
# ..                                                ...
# 95  POLYGON ((3498959.931 562703.503, 3499000.074 ...
# 96  POLYGON ((2974612.984 959763.024, 2974928.771 ...
# 97  MULTIPOLYGON (((2711463.894 929406.954, 271156...
# 98  POLYGON ((1290014.227 2323361.153, 1290965.908...
# 99  POLYGON ((2826204.534 813800.345, 2826633.737 ...
#
#                             NOM_ENT                     NOM_MUN  \
# 0                  Ciudad de México                  Iztapalapa
# 1                   Baja California                     Tijuana
# 2                            México         Ecatepec de Morelos
# 3                        Guanajuato                        León
# 4                            Puebla                      Puebla
# ..                              ...                         ...
# 95                          Chiapas  San Cristóbal de las Casas
# 96  Veracruz de Ignacio de la Llave        Poza Rica de Hidalgo
# 97                        Querétaro            San Juan del Río
# 98                           Sonora       San Luis Río Colorado
# 99                           México                      Chalco
#
#                        NOM_LOC   POBTOT
# 0                   Iztapalapa  1835486
# 1                      Tijuana  1810645
# 2          Ecatepec de Morelos  1643623
# 3           León de los Aldama  1579803
# 4   Heroica Puebla de Zaragoza  1542232
# ..                         ...      ...
# 95  San Cristóbal de las Casas   183509
# 96        Poza Rica de Hidalgo   180057
# 97            San Juan del Río   177719
# 98       San Luis Río Colorado   176685
# 99  Chalco de Díaz Covarrubias   174704
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Save as shapefiles

# %%
# save data to shapefiles
folder = 'mexico_top100_cities_by_population_shp'
filepath = pathlib.Path(folder) / "mexico_top100_cities_by_population.shp"
# if save folder does not already exist, create it
filepath.parent.mkdir(parents=True, exist_ok=True)
mexico_pop_top100.to_file(filepath)

# %% [markdown]
# ## Load saved shapefiles

# %%
top100 = gpd.read_file('mexico_top100_cities_by_population_shp/mexico_top100_cities_by_population.shp')

# %% [markdown]
# ## Prepare queries for downloading graphs of the cities

# %%
gdf = top100

# %%
# project it for CRS 3857 to have it in meter units
gdf = gdf.to_crs(epsg=3857)

# %%
# get area of each city, in meters (as it is already in a CRS with meter unit)
def get_area(geometry):
    return geometry.area

gdf['area_m'] = gdf['geometry'].map(get_area)

# %%
# project it from CRS 3857 to 4326 for OSM
gdf = gdf.to_crs(epsg=4326)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# where to save networks
gdf['entidad_folder'] = gdf.apply(lambda row: '{}_{}'.format(row['CVE_ENT'], row['NOM_ENT']).replace(' ', '-'), axis=1)
gdf['municipio_folder'] = gdf.apply(lambda row: '{}_{}'.format(row['CVE_MUN'], row['NOM_MUN']).replace(' ', '-'), axis=1)
gdf['localidad_folder'] = gdf.apply(lambda row: '{}/{}/{}_{}'.format(row['entidad_folder'],
                                                                     row['municipio_folder'],
                                                                     row['CVE_LOC'], row['NOM_LOC']).replace(' ', '-'), axis=1)

# %%
# create list of queries
queries = gdf.apply(lambda row: {'localidad_folder':row['localidad_folder'], 
                                 'geometry':row['geometry'],
                                 'area_m':row['area_m'],
                                 'POBTOT':row['POBTOT']}, axis=1).tolist()
queries[0]
# Out:
# {'localidad_folder': '09_Ciudad-de-México/007_Iztapalapa/0001_Iztapalapa',
#  'geometry': <shapely.geometry.polygon.Polygon at 0x7fce4fe6f0a0>,
#  'area_m': 127684813.66466376,
#  'POBTOT': 1835486}

# %% [markdown]
# ## Download road network graphs from polygons of the cities

# %%
output_folder = './mexico_cities_graphs/' #where to save graph shapefiles and graphml

# %%
network_type = 'drive'
retain_all = True
buffer = False

# %%
start_time = time.time()
for query in queries:
    try:
        # load graph and save it if it hasn't already been saved in the output_path
        if not os.path.exists('{}/{}.graphml'.format(output_folder, query['localidad_folder'])):
            geometry = query['geometry'].buffer(0) #fix trivially invalid geometries (nested shells, ring self-intersections)
            G = ox.graph_from_polygon(polygon=geometry, network_type=network_type, retain_all=retain_all)
            G.graph['name'] = query['localidad_folder']
            G.graph['area_m'] = query['area_m']
            G.graph['POBTOT'] = query['POBTOT']
            ox.save_graph_shapefile(G, filepath=output_folder+query['localidad_folder'], directed=True)
            ox.save_graphml(G, filepath=output_folder+'{}.graphml'.format(query['localidad_folder']))
    except Exception as e:
        print('"{}" failed: {}'.format(query['localidad_folder'], e))
print('Finished making graphs in {:,.2f} seconds'.format(time.time()-start_time))
# Out:
# /home/alejandro/anaconda3/envs/road-network-project/lib/python3.8/site-packages/osmnx/io.py:108: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)
# Finished making graphs in 3,248.62 seconds

# %% [markdown]
# ## Make a DataFrame of all the cities that have .graphml files saved in the folder

# %%
data_folder = 'mexico_cities_graphs'

# %%
places = []
for entidad_folder in os.listdir(data_folder):
    for municipio_folder in os.listdir('{}/{}'.format(data_folder, entidad_folder)):
        for localidad_file in os.listdir('{}/{}/{}'.format(data_folder, entidad_folder, municipio_folder)):
                if '.graphml' in localidad_file:
                    data = {}
                    data['CVE_ENT'] = entidad_folder.split('_')[0]
                    data['NOM_ENT'] = entidad_folder.replace('{}_'.format(data['CVE_ENT']), '').replace('-', ' ')
                    data['CVE_MUN'] = municipio_folder.split('_')[0]
                    data['NOM_MUN'] = municipio_folder.replace('{}_'.format(data['CVE_MUN']), '').replace('-', ' ')
                    data['CVE_LOC'] = localidad_file.split('_')[0]
                    #data['town'] = town_folder.split('_')[1]
                    data['NOM_LOC'] = localidad_file.replace('{}_'.format(data['CVE_LOC']), '').replace('.graphml', '').replace('-', ' ')
                    data['CVEGEO'] = data['CVE_ENT']+data['CVE_MUN']+data['CVE_LOC']
                    data['path'] = '{}/{}/{}'.format(data_folder, entidad_folder, municipio_folder)
                    data['file'] = localidad_file
                    places.append(data)

df = pd.DataFrame(places)

# %%
df
# Out:
#    CVE_ENT    NOM_ENT CVE_MUN                NOM_MUN CVE_LOC  \
# 0       26     Sonora     018                 Cajeme    0001
# 1       26     Sonora     030             Hermosillo    0001
# 2       26     Sonora     055  San Luis Río Colorado    0001
# 3       26     Sonora     043                Nogales    0001
# 4       22  Querétaro     016       San Juan del Río    0001
# ..     ...        ...     ...                    ...     ...
# 95      15     México     104    Tlalnepantla de Baz    0001
# 96      15     México     106                 Toluca    0001
# 97      15     México     060         Nicolás Romero    0001
# 98      21     Puebla     114                 Puebla    0001
# 99      21     Puebla     156               Tehuacán    0001
#
#                        NOM_LOC     CVEGEO  \
# 0               Ciudad Obregón  260180001
# 1                   Hermosillo  260300001
# 2        San Luis Río Colorado  260550001
# 3              Heroica Nogales  260430001
# 4             San Juan del Río  220160001
# ..                         ...        ...
# 95                Tlalnepantla  151040001
# 96             Toluca de Lerdo  151060001
# 97       Ciudad Nicolás Romero  150600001
# 98  Heroica Puebla de Zaragoza  211140001
# 99                    Tehuacán  211560001
#
#                                                  path  \
# 0           mexico_cities_graphs/26_Sonora/018_Cajeme
# 1       mexico_cities_graphs/26_Sonora/030_Hermosillo
# 2   mexico_cities_graphs/26_Sonora/055_San-Luis-Rí...
# 3          mexico_cities_graphs/26_Sonora/043_Nogales
# 4   mexico_cities_graphs/22_Querétaro/016_San-Juan...
# ..                                                ...
# 95  mexico_cities_graphs/15_México/104_Tlalnepantl...
# 96          mexico_cities_graphs/15_México/106_Toluca
# 97  mexico_cities_graphs/15_México/060_Nicolás-Romero
# 98          mexico_cities_graphs/21_Puebla/114_Puebla
# 99        mexico_cities_graphs/21_Puebla/156_Tehuacán
#
#                                        file
# 0               0001_Ciudad-Obregón.graphml
# 1                   0001_Hermosillo.graphml
# 2        0001_San-Luis-Río-Colorado.graphml
# 3              0001_Heroica-Nogales.graphml
# 4             0001_San-Juan-del-Río.graphml
# ..                                      ...
# 95                0001_Tlalnepantla.graphml
# 96             0001_Toluca-de-Lerdo.graphml
# 97       0001_Ciudad-Nicolás-Romero.graphml
# 98  0001_Heroica-Puebla-de-Zaragoza.graphml
# 99                    0001_Tehuacán.graphml
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Add total population for sorting and calculation of stats in descendent order

# %%
pobtot = gdf[['CVEGEO', 'POBTOT']]

# %%
df = df.merge(pobtot, on=['CVEGEO'], how='inner')
df = df_pob.sort_values(by=['POBTOT'], ascending=False)
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Load graph and calculate stats for each city

# %%
def load_graph_get_stats(row):
    
    try:
        start_time = time.time()
        print('START {}/{}'.format(row['path'], row['file']))
        G = ox.load_graphml(filepath=row['path']+'/'+row['file'])
        G = ox.project_graph(G, to_crs=3857) # project graph to CRS pseudo-UTM with meter units
        area_m = float(G.graph['area_m'])
        
        # calculate basic stats
        stats = ox.basic_stats(G, area=area_m, clean_intersects=True, circuity_dist='euclidean')
        
        stats['CVEGEO'] = row['CVEGEO']
        stats['CVE_ENT'] = row['CVE_ENT']
        stats['NOM_ENT'] = row['NOM_ENT']
        stats['CVE_MUN'] = row['CVE_MUN']
        stats['NOM_MUN'] = row['NOM_MUN']
        stats['CVE_LOC'] = row['CVE_LOC']
        stats['NOM_LOC'] = row['NOM_LOC']
        
        # calculate extended stats excluding shortest paths length, eccentricity, diameter, radius, center
        
        # Convert MultiDiGraph to DiGraph.
        # Chooses between parallel edges by minimizing weight attribute value.
        D = ox.utils_graph.get_digraph(G, weight="length")
        # create undirected Graph from the DiGraph, for those metrics that need it
        Gu = nx.Graph(D)
        
         # average degree of the neighborhood of each node, and average for graph
        avg_neighbor_degree = nx.average_neighbor_degree(G)
        stats["avg_neighbor_degree"] = avg_neighbor_degree
        stats["avg_neighbor_degree_avg"] = sum(avg_neighbor_degree.values()) / len(avg_neighbor_degree)
        
        # avg weighted degree of neighborhood of each node, and average for graph
        avg_wtd_nbr_deg = nx.average_neighbor_degree(G, weight="length")
        stats["avg_weighted_neighbor_degree"] = avg_wtd_nbr_deg
        stats["avg_weighted_neighbor_degree_avg"] = sum(avg_wtd_nbr_deg.values()) / len(avg_wtd_nbr_deg)
        
        # degree centrality for a node is the fraction of nodes it is connected to
        degree_centrality = nx.degree_centrality(G)
        stats["degree_centrality"] = degree_centrality
        stats["degree_centrality_avg"] = sum(degree_centrality.values()) / len(degree_centrality)
        
        # calculate clustering coefficient for the nodes
        stats["clustering_coefficient"] = nx.clustering(Gu)
        
        # average clustering coefficient for the graph
        stats["clustering_coefficient_avg"] = nx.average_clustering(Gu)
        
        # calculate weighted clustering coefficient for the nodes
        stats["clustering_coefficient_weighted"] = nx.clustering(Gu, weight="length")
        
        # average clustering coefficient (weighted) for the graph
        stats["clustering_coefficient_weighted_avg"] = nx.average_clustering(Gu, weight="length")
        
        # pagerank: a ranking of the nodes in the graph based on the structure of
        # the incoming links
        pagerank = nx.pagerank(D, weight="length")
        stats["pagerank"] = pagerank
        
        # node with the highest page rank, and its value
        pagerank_max_node = max(pagerank, key=lambda x: pagerank[x])
        stats["pagerank_max_node"] = pagerank_max_node
        stats["pagerank_max"] = pagerank[pagerank_max_node]
        
        # node with the lowest page rank, and its value
        pagerank_min_node = min(pagerank, key=lambda x: pagerank[x])
        stats["pagerank_min_node"] = pagerank_min_node
        stats["pagerank_min"] = pagerank[pagerank_min_node]
        
        # betweenness centrality of a node is the sum of the fraction of
        # all-pairs shortest paths that pass through node. nx2.4+
        # implementation cannot run on Multi(Di)Graphs, so use DiGraph
        btwn_cent = nx.betweenness_centrality(D, weight="length")
        stats["betweenness_centrality"] = btwn_cent
        stats["betweenness_centrality_avg"] = sum(btwn_cent.values()) / len(btwn_cent)
        
        # closeness centrality of a node is the reciprocal of the sum of the
        # shortest path distances from u to all other nodes
        close_cent = nx.closeness_centrality(G, distance="length")
        stats["closeness_centrality"] = close_cent
        stats["closeness_centrality_avg"] = sum(close_cent.values()) / len(close_cent)
        
        # extract nodes of the largest connected component 
        node_list = [node for node in close_cent]
        stats['nodes'] = node_list
                
        stats['area_km'] = area_m / 1e6
        stats['area'] = area_m
        stats['time'] = time.time()-start_time
        print('FINISH {}/{} in {} seconds'.format(row['path'], row['file'], stats['time']))
        return pd.Series(stats)

    except Exception as e:
        print('{}/{} failed: {}'.format(row['path'], row['file'], e))
        return pd.Series()

# %%
# first 50
df50 = df.head(50)

# %%
# %%time
stats = df50.apply(load_graph_get_stats, axis=1)
# Out:
# START mexico_cities_graphs/09_Ciudad-de-México/007_Iztapalapa/0001_Iztapalapa.graphml
# FINISH mexico_cities_graphs/09_Ciudad-de-México/007_Iztapalapa/0001_Iztapalapa.graphml in 10056.798384904861 seconds
# START mexico_cities_graphs/02_Baja-California/004_Tijuana/0001_Tijuana.graphml

# %%
df50
# Out:
#    CVE_ENT                          NOM_ENT CVE_MUN                NOM_MUN  \
# 0       09                 Ciudad de México     007             Iztapalapa
# 1       02                  Baja California     004                Tijuana
# 2       15                           México     033    Ecatepec de Morelos
# 3       11                       Guanajuato     020                   León
# 4       21                           Puebla     114                 Puebla
# 5       08                        Chihuahua     037                 Juárez
# 6       14                          Jalisco     039            Guadalajara
# 7       14                          Jalisco     120                Zapopan
# 8       09                 Ciudad de México     005      Gustavo A. Madero
# 9       19                       Nuevo León     039              Monterrey
# 10      15                           México     058         Nezahualcóyotl
# 11      08                        Chihuahua     019              Chihuahua
# 12      31                          Yucatán     050                 Mérida
# 13      23                     Quintana Roo     005          Benito Juárez
# 14      05             Coahuila de Zaragoza     030               Saltillo
# 15      01                   Aguascalientes     001         Aguascalientes
# 16      26                           Sonora     030             Hermosillo
# 17      02                  Baja California     002               Mexicali
# 18      24                  San Luis Potosí     028        San Luis Potosí
# 19      25                          Sinaloa     006               Culiacán
# 20      22                        Querétaro     014              Querétaro
# 21      15                           México     057    Naucalpan de Juárez
# 22      09                 Ciudad de México     010         Álvaro Obregón
# 23      16              Michoacán de Ocampo     053                Morelia
# 24      15                           México     031           Chimalhuacán
# 25      28                       Tamaulipas     032                Reynosa
# 26      05             Coahuila de Zaragoza     035                Torreón
# 27      15                           México     104    Tlalnepantla de Baz
# 28      12                         Guerrero     001     Acapulco de Juárez
# 29      14                          Jalisco     098  San Pedro Tlaquepaque
# 30      19                       Nuevo León     026              Guadalupe
# 31      10                          Durango     005                Durango
# 32      09                 Ciudad de México     003               Coyoacán
# 33      09                 Ciudad de México     012                Tlalpan
# 34      07                          Chiapas     101       Tuxtla Gutiérrez
# 35      09                 Ciudad de México     015             Cuauhtémoc
# 36      19                       Nuevo León     006                Apodaca
# 37      15                           México     013   Atizapán de Zaragoza
# 38      15                           México     121     Cuautitlán Izcalli
# 39      28                       Tamaulipas     022              Matamoros
# 40      19                       Nuevo León     021       General Escobedo
# 41      11                       Guanajuato     017               Irapuato
# 42      09                 Ciudad de México     017    Venustiano Carranza
# 43      30  Veracruz de Ignacio de la Llave     087                 Xalapa
# 44      14                          Jalisco     101                 Tonalá
# 45      25                          Sinaloa     012               Mazatlán
# 46      09                 Ciudad de México     014          Benito Juárez
# 47      09                 Ciudad de México     002           Azcapotzalco
# 48      09                 Ciudad de México     013             Xochimilco
# 49      28                       Tamaulipas     027           Nuevo Laredo
#
#    CVE_LOC                     NOM_LOC     CVEGEO  \
# 0     0001                  Iztapalapa  090070001
# 1     0001                     Tijuana  020040001
# 2     0001         Ecatepec de Morelos  150330001
# 3     0001          León de los Aldama  110200001
# 4     0001  Heroica Puebla de Zaragoza  211140001
# 5     0001                      Juárez  080370001
# 6     0001                 Guadalajara  140390001
# 7     0001                     Zapopan  141200001
# 8     0001           Gustavo A. Madero  090050001
# 9     0001                   Monterrey  190390001
# 10    0001       Ciudad Nezahualcóyotl  150580001
# 11    0001                   Chihuahua  080190001
# 12    0001                      Mérida  310500001
# 13    0001                      Cancún  230050001
# 14    0001                    Saltillo  050300001
# 15    0001              Aguascalientes  010010001
# 16    0001                  Hermosillo  260300001
# 17    0001                    Mexicali  020020001
# 18    0001             San Luis Potosí  240280001
# 19    0001            Culiacán Rosales  250060001
# 20    0001       Santiago de Querétaro  220140001
# 21    0001         Naucalpan de Juárez  150570001
# 22    0001              Álvaro Obregón  090100001
# 23    0001                     Morelia  160530001
# 24    0001                Chimalhuacán  150310001
# 25    0001                     Reynosa  280320001
# 26    0001                     Torreón  050350001
# 27    0001                Tlalnepantla  151040001
# 28    0001          Acapulco de Juárez  120010001
# 29    0001                 Tlaquepaque  140980001
# 30    0001                   Guadalupe  190260001
# 31    0001         Victoria de Durango  100050001
# 32    0001                    Coyoacán  090030001
# 33    0001                     Tlalpan  090120001
# 34    0001            Tuxtla Gutiérrez  071010001
# 35    0001                  Cuauhtémoc  090150001
# 36    0001              Ciudad Apodaca  190060001
# 37    0001         Ciudad López Mateos  150130001
# 38    0001          Cuautitlán Izcalli  151210001
# 39    0001           Heroica Matamoros  280220001
# 40    0001     Ciudad General Escobedo  190210001
# 41    0001                    Irapuato  110170001
# 42    0001         Venustiano Carranza  090170001
# 43    0001             Xalapa Enríquez  300870001
# 44    0001                      Tonalá  141010001
# 45    0001                    Mazatlán  250120001
# 46    0001               Benito Juárez  090140001
# 47    0001                Azcapotzalco  090020001
# 48    0001                  Xochimilco  090130001
# 49    0001                Nuevo Laredo  280270001
#
#                                                  path  \
# 0   mexico_cities_graphs/09_Ciudad-de-México/007_I...
# 1   mexico_cities_graphs/02_Baja-California/004_Ti...
# 2   mexico_cities_graphs/15_México/033_Ecatepec-de...
# 3         mexico_cities_graphs/11_Guanajuato/020_León
# 3           0001_León-de-los-Aldama.graphml  1579803
# 4   0001_Heroica-Puebla-de-Zaragoza.graphml  1542232
# 5                       0001_Juárez.graphml  1501551
# 6                  0001_Guadalajara.graphml  1385621
# 7                      0001_Zapopan.graphml  1257547
# 8            0001_Gustavo-A.-Madero.graphml  1173351
# 9                    0001_Monterrey.graphml  1142952
# 10       0001_Ciudad-Nezahualcóyotl.graphml  1072676
# 11                   0001_Chihuahua.graphml   925762
# 12                      0001_Mérida.graphml   921771
# 13                      0001_Cancún.graphml   888797
# 14                    0001_Saltillo.graphml   864431
# 15              0001_Aguascalientes.graphml   863893
# 16                  0001_Hermosillo.graphml   855563
# 17                    0001_Mexicali.graphml   854186
# 18             0001_San-Luis-Potosí.graphml   845941
# 19            0001_Culiacán-Rosales.graphml   808416
# 20       0001_Santiago-de-Querétaro.graphml   794789
# 21         0001_Naucalpan-de-Juárez.graphml   776220
# 22              0001_Álvaro-Obregón.graphml   759003
# 23                     0001_Morelia.graphml   743275
# 24                0001_Chimalhuacán.graphml   703215
# 25                     0001_Reynosa.graphml   691557
# 26                     0001_Torreón.graphml   690193
# 27                0001_Tlalnepantla.graphml   658907
# 28          0001_Acapulco-de-Juárez.graphml   658609
# 29                 0001_Tlaquepaque.graphml   650123
# 30                   0001_Guadalupe.graphml   635862
# 31         0001_Victoria-de-Durango.graphml   616068
# 32                    0001_Coyoacán.graphml   614447
# 33                     0001_Tlalpan.graphml   599935
# 34            0001_Tuxtla-Gutiérrez.graphml   578830
# 35                  0001_Cuauhtémoc.graphml   545884
# 36              0001_Ciudad-Apodaca.graphml   536436
# 37         0001_Ciudad-López-Mateos.graphml   523065
# 38          0001_Cuautitlán-Izcalli.graphml   515353
# 39           0001_Heroica-Matamoros.graphml   510739
# 40     0001_Ciudad-General-Escobedo.graphml   454967
# 41                    0001_Irapuato.graphml   452090
# 42         0001_Venustiano-Carranza.graphml   443704
# 43             0001_Xalapa-Enríquez.graphml   443063
# 44                      0001_Tonalá.graphml   442440
# 45                    0001_Mazatlán.graphml   441975
# 46               0001_Benito-Juárez.graphml   434153
# 47                0001_Azcapotzalco.graphml   432205
# 48                  0001_Xochimilco.graphml   429481
# 49                0001_Nuevo-Laredo.graphml   416055

# %%
df.tail(50)
# Out:
#    CVE_ENT                          NOM_ENT CVE_MUN  \
# 50      09                 Ciudad de México     016
# 51      19                       Nuevo León     046
# 52      30  Veracruz de Ignacio de la Llave     193
# 53      09                 Ciudad de México     006
# 54      15                           México     081
# 55      15                           México     122
# 56      11                       Guanajuato     007
# 57      18                          Nayarit     017
# 58      15                           México     039
# 59      17                          Morelos     007
# 60      27                          Tabasco     004
# 61      28                       Tamaulipas     041
# 62      02                  Baja California     001
# 63      26                           Sonora     018
# 64      09                 Ciudad de México     011
# 65      15                           México     060
# 66      24                  San Luis Potosí     035
# 67      19                       Nuevo León     031
# 68      23                     Quintana Roo     008
# 69      19                       Nuevo León     048
# 70      10                          Durango     007
# 71      16              Michoacán de Ocampo     102
# 72      25                          Sinaloa     001
# 73      13                          Hidalgo     048
# 74      28                       Tamaulipas     038
# 75      21                           Puebla     156
# 76      15                           México     020
# 77      26                           Sonora     043
# 78      20                           Oaxaca     067
# 79      03              Baja California Sur     003
# 80      04                         Campeche     002
# 81      09                 Ciudad de México     008
# 82      05             Coahuila de Zaragoza     018
# 83      19                       Nuevo León     018
# 84      12                         Guerrero     029
# 85      14                          Jalisco     067
# 86      15                           México     106
# 87      07                          Chiapas     089
# 88      15                           México     109
# 89      30  Veracruz de Ignacio de la Llave     039
# 90      28                       Tamaulipas     009
# 91      03              Baja California Sur     008
# 92      15                           México     029
# 93      04                         Campeche     003
# 94      09                 Ciudad de México     004
# 95      07                          Chiapas     078
# 96      30  Veracruz de Ignacio de la Llave     131
# 97      22                        Querétaro     016
# 98      26                           Sonora     055
# 99      15                           México     025
#
#                         NOM_MUN CVE_LOC                         NOM_LOC  \
# 50               Miguel Hidalgo    0001                  Miguel Hidalgo
# 51     San Nicolás de los Garza    0001        San Nicolás de los Garza
# 52                     Veracruz    0001                        Veracruz
# 53                    Iztacalco    0001                       Iztacalco
# 54                      Tecámac    0019                     Ojo de Agua
# 55  Valle de Chalco Solidaridad    0001                            Xico
# 56                       Celaya    0001                          Celaya
# 57                        Tepic    0001                           Tepic
# 58                   Ixtapaluca    0001                      Ixtapaluca
# 59                   Cuernavaca    0001                      Cuernavaca
# 60                       Centro    0001                    Villahermosa
# 61                     Victoria    0001                 Ciudad Victoria
# 62                     Ensenada    0001                        Ensenada
# 63                       Cajeme    0001                  Ciudad Obregón
# 64                      Tláhuac    0001                         Tláhuac
# 65               Nicolás Romero    0001           Ciudad Nicolás Romero
# 66  Soledad de Graciano Sánchez    0001     Soledad de Graciano Sánchez
# 67                       Juárez    0001            Ciudad Benito Juárez
# 68                  Solidaridad    0001                Playa del Carmen
# 69               Santa Catarina    0001           Ciudad Santa Catarina
# 70                Gómez Palacio    0001                   Gómez Palacio
# 71                      Uruapan    0001                         Uruapan
# 72                        Ahome    0001                      Los Mochis
# 73              Pachuca de Soto    0001                 Pachuca de Soto
# 74                      Tampico    0001                         Tampico
# 75                     Tehuacán    0001                        Tehuacán
# 76      Coacalco de Berriozábal    0001          San Francisco Coacalco
# 77                      Nogales    0001                 Heroica Nogales
# 78             Oaxaca de Juárez    0001                Oaxaca de Juárez
# 79                       La Paz    0001                          La Paz
# 80                     Campeche    0001       San Francisco de Campeche
# 81       La Magdalena Contreras    0001          La Magdalena Contreras
# 82                     Monclova    0001                        Monclova
# 83                       García    0001                          García
# 84    Chilpancingo de los Bravo    0001       Chilpancingo de los Bravo
# 85              Puerto Vallarta    0001                 Puerto Vallarta
# 86                       Toluca    0001                 Toluca de Lerdo
# 87                    Tapachula    0001  Tapachula de Córdova y Ordóñez
# 88                    Tultitlán    0003                      Buenavista
# 89                Coatzacoalcos    0001                   Coatzacoalcos
# 90                Ciudad Madero    0001                   Ciudad Madero
# 91                    Los Cabos    0054                  Cabo San Lucas
# 92                  Chicoloapan    0001           Chicoloapan de Juárez
# 93                       Carmen    0001               Ciudad del Carmen
# 94        Cuajimalpa de Morelos    0001           Cuajimalpa de Morelos
# 95   San Cristóbal de las Casas    0001      San Cristóbal de las Casas
# 96         Poza Rica de Hidalgo    0001            Poza Rica de Hidalgo
